# %%
from gettext import npgettext
from IPython.display import display
import numpy as np 
import pandas as pd

masked = pd.read_csv("C:/Users/Graduate/Desktop/Trackers (EXCEL)/tracker_weight/CBUM/CSV/Masked.csv")

# %%
print(masked.columns)
# Out:
# Index(['Exercise Name', 'Muscle Group Tag', 'Set 1', 'Weight 1', 'Set 2',
#        'Weight 2', 'Set 3', 'Weight 3', 'Set 4', 'Weight 4',
#        'Total Effort Calculation'],
#       dtype='object')

# %%
cols = masked.columns

# %%
masked[cols].memory_usage(deep=True).sum()

# %%
masked[cols].dtypes
# Out:
# Exercise Name                object
# Muscle Group Tag             object
# Set 1                         int64
# Weight 1                      int64
# Set 2                         int64
# Weight 2                      int64
# Set 3                       float64
# Weight 3                    float64
# Set 4                       float64
# Weight 4                    float64
# Total Effort Calculation      int64
# dtype: object

# %%
#perform a float transform to ensure data is always a float
masked.iloc[:,[2,3,4,5,6,7,8,9,10]].astype(float)
# Out:
#     Set 1  Weight 1  Set 2  Weight 2  Set 3  Weight 3  Set 4  Weight 4  \
# 0     8.0     150.0    8.0     175.0    8.0     200.0    7.0     205.0
# 1    10.0      60.0   10.0      60.0   10.0      60.0    NaN       NaN
# 2    12.0      50.0   12.0      50.0   12.0      50.0    NaN       NaN
# 3    14.0     115.0   12.0     115.0   95.0      15.0   95.0      14.0
# 4    13.0     168.0    7.0     109.0   11.0     226.0   11.0     105.0
# 5    11.0     160.0   11.0     226.0   12.0     172.0    9.0     118.0
# 6     8.0     148.0    6.0     132.0    6.0     133.0   14.0     118.0
# 7    11.0     236.0   12.0     241.0   11.0     101.0   15.0     129.0
# 8    10.0     248.0   14.0     232.0   13.0     222.0   14.0     158.0
# 9     8.0     171.0   10.0     186.0   11.0     197.0   10.0     244.0
# 10   11.0     121.0   11.0     121.0    8.0     103.0    NaN       NaN
# 11   13.0     205.0    7.0     217.0   15.0     122.0    NaN       NaN
# ...

# %%
#create an effort for Set 1-4 for each exercise

for i = 0, i < masked.shape[0]
    count = i+1
    set_1 = masked.iloc[i,2]
    weight_1 = masked.iloc[i,3]
    Execercises_Effort_1 = [i, set_1*weight_1]
    return exercise_effort_1[]
# Out:
#   Cell In[42], line 3
#     for i = 0, i < masked.shape[0]
#           ^
# SyntaxError: invalid syntax
