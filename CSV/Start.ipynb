# %%
from gettext import npgettext
from IPython.display import display
import numpy as np 
import pandas as pd

# %%
workout_sheet = pd.read_csv(r"C:\Users\Graduate\Desktop\Trackers (EXCEL)\CBUM\CSV\Leg.csv")

# %%
workout_sheet
# Out:
#                      Exercise Name Muscle Group Tag  Set 1  Weight 1  Set 2  \
# 0               Hack Squat Machine            Quads    8.0     150.0    8.0
# 1           Bulgarian Split Squats            Quads   10.0      60.0   10.0
# 2                  Landmine Squats            Quads   12.0      50.0   12.0
# 3                   Leg Extensions            Quads   14.0     115.0   12.0
# 4            Isolateral Flat Press            Chest    NaN       NaN    NaN
# 5                 Incline DB Press            Chest    NaN       NaN    NaN
# 6                  Cable Chest Fly            Chest    NaN       NaN    NaN
# 7          Cable Triceps Pushdowns          Triceps    NaN       NaN    NaN
# 8        Overhead Cable Extensions          Triceps    NaN       NaN    NaN
# 9                   Lateral Raises        Shoulders    NaN       NaN    NaN
# 10                    Lat Pulldown             Lats    NaN       NaN    NaN
# ...

# %%
workout_sheet.columns
# Out:
# Index(['Exercise Name', 'Muscle Group Tag', 'Set 1', 'Weight 1', 'Set 2',
#        'Weight 2', 'Set 3', 'Weight 3', 'Set 4', 'Weight 4',
#        'Total Effort Calculation'],
#       dtype='object')

# %%
workout_sheet[cols].memory_usage(deep=true).sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 workout_sheet[cols].memory_usage(deep=true).sum()
#
# NameError: name 'cols' is not defined
